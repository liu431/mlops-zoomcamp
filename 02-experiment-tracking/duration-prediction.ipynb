# %%
# !python -V
# Out:
# Python 3.9.12

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# 2022/05/29 15:21:54 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2022/05/29 15:21:54 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> 451aebb31d03, add metric step
# INFO  [alembic.runtime.migration] Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# INFO  [alembic.runtime.migration] Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# INFO  [alembic.runtime.migration] Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# INFO  [alembic.runtime.migration] Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# INFO  [alembic.runtime.migration] Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# INFO  [89d4b8295536_create_latest_metrics_table_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Adding registered_models and model_versions tables to database.
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# INFO  [alembic.runtime.migration] Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# INFO  [alembic.runtime.migration] Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# INFO  [alembic.runtime.migration] Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# INFO  [alembic.runtime.migration] Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# INFO  [alembic.runtime.migration] Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# INFO  [alembic.runtime.migration] Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# INFO  [alembic.runtime.migration] Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# INFO  [alembic.runtime.migration] Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2022/05/29 15:21:55 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='./mlruns/1', experiment_id='1', lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('../data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('../data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.479618227604778

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "lliu")

    mlflow.log_param("train-data-path", "../data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "../data/green_tripdata_2021-02.parquet")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [18:15:28] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:8.11768
# [1]	validation-rmse:6.78819
# [2]	validation-rmse:6.62610
# [3]	validation-rmse:6.59686
# [4]	validation-rmse:6.58548
# [5]	validation-rmse:6.57767
# [6]	validation-rmse:6.57038
# [7]	validation-rmse:6.55866
# [8]	validation-rmse:6.55095
# [9]	validation-rmse:6.54555
# [10]	validation-rmse:6.53899
# [11]	validation-rmse:6.53166
# [12]	validation-rmse:6.52512
# [13]	validation-rmse:6.51983
# [14]	validation-rmse:6.51450
# [15]	validation-rmse:6.50811
# [16]	validation-rmse:6.50498
# [17]	validation-rmse:6.50093
# [18]	validation-rmse:6.49245
# [19]	validation-rmse:6.49054
# [20]	validation-rmse:6.48588
# [21]	validation-rmse:6.48115
# [22]	validation-rmse:6.47897
# [23]	validation-rmse:6.47707
# [24]	validation-rmse:6.47802
# [25]	validation-rmse:6.47589
# [26]	validation-rmse:6.47327
# [27]	validation-rmse:6.46770
# [28]	validation-rmse:6.46516
# [29]	validation-rmse:6.46367
# [30]	validation-rmse:6.46037
# [31]	validation-rmse:6.45784
# [32]	validation-rmse:6.45619
# [33]	validation-rmse:6.45437
# [34]	validation-rmse:6.45224
# [35]	validation-rmse:6.45142
# [36]	validation-rmse:6.44980
# [37]	validation-rmse:6.44822
# [38]	validation-rmse:6.44724
# [39]	validation-rmse:6.44644
# [40]	validation-rmse:6.44668
# [41]	validation-rmse:6.44753
# [42]	validation-rmse:6.44594
# [43]	validation-rmse:6.44517
# [44]	validation-rmse:6.44517
# [45]	validation-rmse:6.44312
# [46]	validation-rmse:6.44061
# [47]	validation-rmse:6.44031
# [48]	validation-rmse:6.43947
# [49]	validation-rmse:6.43879
# [50]	validation-rmse:6.43757
# [51]	validation-rmse:6.43736
# [52]	validation-rmse:6.43728
# [53]	validation-rmse:6.43584
# [54]	validation-rmse:6.43537
# [55]	validation-rmse:6.43528
# [56]	validation-rmse:6.43424
# [57]	validation-rmse:6.43459
# [58]	validation-rmse:6.43264
# [59]	validation-rmse:6.43283
# [60]	validation-rmse:6.43062
# [61]	validation-rmse:6.42586
# [62]	validation-rmse:6.42369
# [63]	validation-rmse:6.42447
# [64]	validation-rmse:6.42616
# [65]	validation-rmse:6.42515
# [66]	validation-rmse:6.42581
# [67]	validation-rmse:6.42497
# [68]	validation-rmse:6.42430
# [69]	validation-rmse:6.42740
# [70]	validation-rmse:6.42793
# [71]	validation-rmse:6.42820
# [72]	validation-rmse:6.42820
# [73]	validation-rmse:6.42773
# [74]	validation-rmse:6.42762
# [75]	validation-rmse:6.42830
# [76]	validation-rmse:6.42748
# [77]	validation-rmse:6.42889
# [78]	validation-rmse:6.42555
# [79]	validation-rmse:6.42489
# [80]	validation-rmse:6.43405
# [81]	validation-rmse:6.43476
# [82]	validation-rmse:6.43428
# [83]	validation-rmse:6.43366
# [84]	validation-rmse:6.42775
# [85]	validation-rmse:6.42838
# [86]	validation-rmse:6.42959
# [87]	validation-rmse:6.43199
# [88]	validation-rmse:6.43170
# [89]	validation-rmse:6.43718
# [90]	validation-rmse:6.43676
# [91]	validation-rmse:6.43854
# [92]	validation-rmse:6.43738
# [93]	validation-rmse:6.43691
# [94]	validation-rmse:6.43623
# [95]	validation-rmse:6.43583
# [96]	validation-rmse:6.43599
# [97]	validation-rmse:6.43602
# [98]	validation-rmse:6.43608
# [99]	validation-rmse:6.43640
# [100]	validation-rmse:6.43688
# [101]	validation-rmse:6.43657
# [102]	validation-rmse:6.43748
# [103]	validation-rmse:6.43746
# [104]	validation-rmse:6.43776
# [105]	validation-rmse:6.43823
# [106]	validation-rmse:6.43933
# [107]	validation-rmse:6.44192
# [108]	validation-rmse:6.44211
# [109]	validation-rmse:6.44203
# [110]	validation-rmse:6.44142
# [111]	validation-rmse:6.44100
# [112]	validation-rmse:6.44151
# [18:15:41] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:6.97375
# [1]	validation-rmse:6.76431
# [2]	validation-rmse:6.74795
# [3]	validation-rmse:6.74041
# [4]	validation-rmse:6.71488
# [5]	validation-rmse:6.70682
# [6]	validation-rmse:6.70170
# [7]	validation-rmse:6.69501
# [8]	validation-rmse:6.69005
# [9]	validation-rmse:6.68445
# [10]	validation-rmse:6.68235
# [11]	validation-rmse:6.67408
# [12]	validation-rmse:6.66924
# [13]	validation-rmse:6.66563
# [14]	validation-rmse:6.66083
# [15]	validation-rmse:6.65752
# [16]	validation-rmse:6.65475
# [17]	validation-rmse:6.65390
# [18]	validation-rmse:6.65214
# [19]	validation-rmse:6.64470
# [20]	validation-rmse:6.64284
# [21]	validation-rmse:6.64090
# [22]	validation-rmse:6.64122
# [23]	validation-rmse:6.63927
# [24]	validation-rmse:6.62934
# [25]	validation-rmse:6.62699
# [26]	validation-rmse:6.62192
# [27]	validation-rmse:6.62083
# [28]	validation-rmse:6.62010
# [29]	validation-rmse:6.61661
# [30]	validation-rmse:6.61501
# [31]	validation-rmse:6.61387
# [32]	validation-rmse:6.61241
# [33]	validation-rmse:6.61024
# [34]	validation-rmse:6.60991
# [35]	validation-rmse:6.60946
# [36]	validation-rmse:6.60760
# [37]	validation-rmse:6.60638
# [38]	validation-rmse:6.60415
# [39]	validation-rmse:6.60420
# [40]	validation-rmse:6.60461
# [41]	validation-rmse:6.60373
# [42]	validation-rmse:6.60678
# [43]	validation-rmse:6.60424
# [44]	validation-rmse:6.60288
# [45]	validation-rmse:6.60160
# [46]	validation-rmse:6.60117
# [47]	validation-rmse:6.60069
# [48]	validation-rmse:6.60057
# [49]	validation-rmse:6.60031
# [50]	validation-rmse:6.59980
# [51]	validation-rmse:6.59880
# [52]	validation-rmse:6.59648
# [53]	validation-rmse:6.59626
# [54]	validation-rmse:6.59415
# [55]	validation-rmse:6.59384
# [56]	validation-rmse:6.59307
# [57]	validation-rmse:6.59266
# [58]	validation-rmse:6.59174
# [59]	validation-rmse:6.59120
# [60]	validation-rmse:6.59085
# [61]	validation-rmse:6.59088
# [62]	validation-rmse:6.59062
# [63]	validation-rmse:6.58993
# [64]	validation-rmse:6.58824
# [65]	validation-rmse:6.58802
# [66]	validation-rmse:6.58745
# [67]	validation-rmse:6.58727
# [68]	validation-rmse:6.58263
# [69]	validation-rmse:6.58190
# [70]	validation-rmse:6.58148
# [71]	validation-rmse:6.58110
# [72]	validation-rmse:6.58014
# [73]	validation-rmse:6.57969
# [74]	validation-rmse:6.58358
# [75]	validation-rmse:6.58350
# [76]	validation-rmse:6.58232
# [77]	validation-rmse:6.58181
# [78]	validation-rmse:6.58179
# [79]	validation-rmse:6.58146
# [80]	validation-rmse:6.58117
# [81]	validation-rmse:6.58066
# [82]	validation-rmse:6.58066
# [83]	validation-rmse:6.57974
# [84]	validation-rmse:6.57896
# [85]	validation-rmse:6.57949
# [86]	validation-rmse:6.57943
# [87]	validation-rmse:6.57853
# [88]	validation-rmse:6.57826
# [89]	validation-rmse:6.57808
# [90]	validation-rmse:6.57961
# [91]	validation-rmse:6.57884
# [92]	validation-rmse:6.57896
# [93]	validation-rmse:6.57856
# [94]	validation-rmse:6.57775
# [95]	validation-rmse:6.57752
# [96]	validation-rmse:6.57737
# [97]	validation-rmse:6.57586
# [98]	validation-rmse:6.57569
# [99]	validation-rmse:6.57726
# [100]	validation-rmse:6.57848
# [101]	validation-rmse:6.57913
# [102]	validation-rmse:6.57984
# [103]	validation-rmse:6.57978
# [104]	validation-rmse:6.57962
# [105]	validation-rmse:6.57988
# [106]	validation-rmse:6.57993
# [107]	validation-rmse:6.57991
# [108]	validation-rmse:6.57970
# [109]	validation-rmse:6.57840
# [110]	validation-rmse:6.57919
# [111]	validation-rmse:6.57940
# [112]	validation-rmse:6.57880
# [113]	validation-rmse:6.57843
# [114]	validation-rmse:6.57824
# [115]	validation-rmse:6.57822
# [116]	validation-rmse:6.57778
# [117]	validation-rmse:6.57771
# [118]	validation-rmse:6.57839
# [119]	validation-rmse:6.57855
# [120]	validation-rmse:6.57786
# [121]	validation-rmse:6.57751
# [122]	validation-rmse:6.57686
# [123]	validation-rmse:6.57729
# [124]	validation-rmse:6.57661
# [125]	validation-rmse:6.57732
# [126]	validation-rmse:6.57677
# [127]	validation-rmse:6.57700
# [128]	validation-rmse:6.57651
# [129]	validation-rmse:6.57673
# [130]	validation-rmse:6.57740
# [131]	validation-rmse:6.57696
# [132]	validation-rmse:6.57681
# [133]	validation-rmse:6.57761
# [134]	validation-rmse:6.58161
# [135]	validation-rmse:6.58421
# [136]	validation-rmse:6.58648
# [137]	validation-rmse:6.58607
# [138]	validation-rmse:6.58613
# [139]	validation-rmse:6.58634
# [140]	validation-rmse:6.58689
# [141]	validation-rmse:6.58645
# [142]	validation-rmse:6.58638
# [143]	validation-rmse:6.58616
# [144]	validation-rmse:6.58692
# [145]	validation-rmse:6.58637
# [146]	validation-rmse:6.58635
# [147]	validation-rmse:6.58618
# [18:15:49] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:20.00080
# [1]	validation-rmse:18.89639
# [2]	validation-rmse:17.87347
# [3]	validation-rmse:16.92667
# [4]	validation-rmse:16.05076
# [5]	validation-rmse:15.24146
# [6]	validation-rmse:14.49472
# [7]	validation-rmse:13.80657
# [8]	validation-rmse:13.17311
# [9]	validation-rmse:12.59123
# [10]	validation-rmse:12.05594
# [11]	validation-rmse:11.56467
# [12]	validation-rmse:11.11486
# [13]	validation-rmse:10.70324
# [14]	validation-rmse:10.32741
# [15]	validation-rmse:9.98544
# [16]	validation-rmse:9.67333
# [17]	validation-rmse:9.38998
# [18]	validation-rmse:9.13195
# [19]	validation-rmse:8.89711
# [20]	validation-rmse:8.68431
# [21]	validation-rmse:8.49127
# [22]	validation-rmse:8.31645
# [23]	validation-rmse:8.15805
# [24]	validation-rmse:8.01496
# [25]	validation-rmse:7.88554
# [26]	validation-rmse:7.76874
# [27]	validation-rmse:7.66251
# [28]	validation-rmse:7.56697
# [29]	validation-rmse:7.48011
# [30]	validation-rmse:7.40224
# [31]	validation-rmse:7.33125
# [32]	validation-rmse:7.26766
# [33]	validation-rmse:7.20958
# [34]	validation-rmse:7.15765
# [35]	validation-rmse:7.10964
# [36]	validation-rmse:7.06583
# [37]	validation-rmse:7.02613
# [38]	validation-rmse:6.99055
# [39]	validation-rmse:6.95778
# [40]	validation-rmse:6.92788
# [41]	validation-rmse:6.90095
# [42]	validation-rmse:6.87601
# [43]	validation-rmse:6.85336
# [44]	validation-rmse:6.83252
# [45]	validation-rmse:6.81384
# [46]	validation-rmse:6.79650
# [47]	validation-rmse:6.78056
# [48]	validation-rmse:6.76593
# [49]	validation-rmse:6.75210
# [50]	validation-rmse:6.74008
# [51]	validation-rmse:6.72836
# [52]	validation-rmse:6.71805
# [53]	validation-rmse:6.70795
# [54]	validation-rmse:6.69878
# [55]	validation-rmse:6.69026
# [56]	validation-rmse:6.68205
# [57]	validation-rmse:6.67516
# [58]	validation-rmse:6.66858
# [59]	validation-rmse:6.66218
# [60]	validation-rmse:6.65667
# [61]	validation-rmse:6.65160
# [62]	validation-rmse:6.64663
# [63]	validation-rmse:6.64165
# [64]	validation-rmse:6.63728
# [65]	validation-rmse:6.63346
# [66]	validation-rmse:6.62960
# [67]	validation-rmse:6.62639
# [68]	validation-rmse:6.62222
# [69]	validation-rmse:6.61942
# [70]	validation-rmse:6.61594
# [71]	validation-rmse:6.61350
# [72]	validation-rmse:6.61073
# [73]	validation-rmse:6.60828
# [74]	validation-rmse:6.60562
# [75]	validation-rmse:6.60328
# [76]	validation-rmse:6.60115
# [77]	validation-rmse:6.59879
# [78]	validation-rmse:6.59671
# [79]	validation-rmse:6.59466
# [80]	validation-rmse:6.59284
# [81]	validation-rmse:6.59047
# [82]	validation-rmse:6.58884
# [83]	validation-rmse:6.58674
# [84]	validation-rmse:6.58547
# [85]	validation-rmse:6.58440
# [86]	validation-rmse:6.58331
# [87]	validation-rmse:6.58228
# [88]	validation-rmse:6.58140
# [89]	validation-rmse:6.58030
# [90]	validation-rmse:6.57892
# [91]	validation-rmse:6.57754
# [92]	validation-rmse:6.57673
# [93]	validation-rmse:6.57595
# [94]	validation-rmse:6.57466
# [95]	validation-rmse:6.57410
# [96]	validation-rmse:6.57304
# [97]	validation-rmse:6.57195
# [98]	validation-rmse:6.57095
# [99]	validation-rmse:6.57036
# [100]	validation-rmse:6.56980
# [101]	validation-rmse:6.56915
# [102]	validation-rmse:6.56862
# [103]	validation-rmse:6.56815
# [104]	validation-rmse:6.56728
# [105]	validation-rmse:6.56657
# [106]	validation-rmse:6.56606
# [107]	validation-rmse:6.56572
# [108]	validation-rmse:6.56516
# [109]	validation-rmse:6.56480
# [110]	validation-rmse:6.56438
# [111]	validation-rmse:6.56377
# [112]	validation-rmse:6.56343
# [113]	validation-rmse:6.56282
# [114]	validation-rmse:6.56264
# [115]	validation-rmse:6.56229
# [116]	validation-rmse:6.56206
# [117]	validation-rmse:6.56171
# [118]	validation-rmse:6.56138
# [119]	validation-rmse:6.56080
# [120]	validation-rmse:6.56061
# [121]	validation-rmse:6.56007
# [122]	validation-rmse:6.55990
# [123]	validation-rmse:6.55965
# [124]	validation-rmse:6.55938
# [125]	validation-rmse:6.55894
# [126]	validation-rmse:6.55863
# [127]	validation-rmse:6.55818
# [128]	validation-rmse:6.55809
# [129]	validation-rmse:6.55780
# [130]	validation-rmse:6.55761
# [131]	validation-rmse:6.55754
# [132]	validation-rmse:6.55744
# [133]	validation-rmse:6.55687
# [134]	validation-rmse:6.55675
# [135]	validation-rmse:6.55655
# [136]	validation-rmse:6.55637
# [137]	validation-rmse:6.55615
# [138]	validation-rmse:6.55587
# [139]	validation-rmse:6.55557
# [140]	validation-rmse:6.55541
# [141]	validation-rmse:6.55542
# [142]	validation-rmse:6.55527
# [143]	validation-rmse:6.55509
# [144]	validation-rmse:6.55483
# [145]	validation-rmse:6.55475
# [146]	validation-rmse:6.55475
# [147]	validation-rmse:6.55462
# [148]	validation-rmse:6.55441
# [149]	validation-rmse:6.55429
# [150]	validation-rmse:6.55401
# [151]	validation-rmse:6.55389
# [152]	validation-rmse:6.55361
# [153]	validation-rmse:6.55339
# [154]	validation-rmse:6.55304
# [155]	validation-rmse:6.55293
# [156]	validation-rmse:6.55264
# [157]	validation-rmse:6.55252
# [158]	validation-rmse:6.55250
# [159]	validation-rmse:6.55251
# [160]	validation-rmse:6.55240
# [161]	validation-rmse:6.55224
# [162]	validation-rmse:6.55216
# [163]	validation-rmse:6.55210
# [164]	validation-rmse:6.55183
# [165]	validation-rmse:6.55170
# [166]	validation-rmse:6.55152
# [167]	validation-rmse:6.55144
# [168]	validation-rmse:6.55125
# [169]	validation-rmse:6.55114
# [170]	validation-rmse:6.55087
# [171]	validation-rmse:6.55067
# [172]	validation-rmse:6.55071
# [173]	validation-rmse:6.55063
# [174]	validation-rmse:6.55051
# [175]	validation-rmse:6.55049
# [176]	validation-rmse:6.55045
# [177]	validation-rmse:6.55028
# [178]	validation-rmse:6.55013
# [179]	validation-rmse:6.54996
# [180]	validation-rmse:6.54991
# [181]	validation-rmse:6.54967
# [182]	validation-rmse:6.54961
# [183]	validation-rmse:6.54962
# [184]	validation-rmse:6.54941
# [185]	validation-rmse:6.54934
# [186]	validation-rmse:6.54940
# [187]	validation-rmse:6.54931
# [188]	validation-rmse:6.54914
# [189]	validation-rmse:6.54906
# [190]	validation-rmse:6.54903
# [191]	validation-rmse:6.54894
# [192]	validation-rmse:6.54878
# [193]	validation-rmse:6.54849
# [194]	validation-rmse:6.54850
# [195]	validation-rmse:6.54841
# [196]	validation-rmse:6.54818
# [197]	validation-rmse:6.54806
# [198]	validation-rmse:6.54801
# [199]	validation-rmse:6.54804
# [200]	validation-rmse:6.54808
# [201]	validation-rmse:6.54800
# [202]	validation-rmse:6.54789
# [203]	validation-rmse:6.54803
# [204]	validation-rmse:6.54784
# [205]	validation-rmse:6.54786
# [206]	validation-rmse:6.54783
# [207]	validation-rmse:6.54766
# [208]	validation-rmse:6.54756
# [209]	validation-rmse:6.54755
# [210]	validation-rmse:6.54756
# [211]	validation-rmse:6.54751
# [212]	validation-rmse:6.54735
# [213]	validation-rmse:6.54728
# [214]	validation-rmse:6.54715
# [215]	validation-rmse:6.54711
# [216]	validation-rmse:6.54708
# [217]	validation-rmse:6.54709
# [218]	validation-rmse:6.54711
# [219]	validation-rmse:6.54697
# [220]	validation-rmse:6.54693
# [221]	validation-rmse:6.54690
# [222]	validation-rmse:6.54675
# [223]	validation-rmse:6.54663
# [224]	validation-rmse:6.54659
# [225]	validation-rmse:6.54656
# [226]	validation-rmse:6.54646
# [227]	validation-rmse:6.54649
# [228]	validation-rmse:6.54649
# [229]	validation-rmse:6.54637
# [230]	validation-rmse:6.54632
# [231]	validation-rmse:6.54627
# [232]	validation-rmse:6.54620
# [233]	validation-rmse:6.54614
# [234]	validation-rmse:6.54603
# [235]	validation-rmse:6.54599
# [236]	validation-rmse:6.54591
# [237]	validation-rmse:6.54576
# [238]	validation-rmse:6.54573
# [239]	validation-rmse:6.54567
# [240]	validation-rmse:6.54564
# [241]	validation-rmse:6.54562
# [242]	validation-rmse:6.54556
# [243]	validation-rmse:6.54569
# [244]	validation-rmse:6.54567
# [245]	validation-rmse:6.54561
# [246]	validation-rmse:6.54550
# [247]	validation-rmse:6.54553
# [248]	validation-rmse:6.54559
# [249]	validation-rmse:6.54550
# [250]	validation-rmse:6.54552
# [251]	validation-rmse:6.54550
# [252]	validation-rmse:6.54562
# [253]	validation-rmse:6.54560
# [254]	validation-rmse:6.54555
# [255]	validation-rmse:6.54550
# [256]	validation-rmse:6.54548
# [257]	validation-rmse:6.54543
# [258]	validation-rmse:6.54552
# [259]	validation-rmse:6.54558
# [260]	validation-rmse:6.54559
# [261]	validation-rmse:6.54554
# [262]	validation-rmse:6.54552
# [263]	validation-rmse:6.54543
# [264]	validation-rmse:6.54539
# [265]	validation-rmse:6.54538
# [266]	validation-rmse:6.54568
# [267]	validation-rmse:6.54570
# [268]	validation-rmse:6.54567
# [269]	validation-rmse:6.54551
# [270]	validation-rmse:6.54554
# [271]	validation-rmse:6.54554
# [272]	validation-rmse:6.54554
# [273]	validation-rmse:6.54547
# [274]	validation-rmse:6.54539
# [275]	validation-rmse:6.54539
# [276]	validation-rmse:6.54537
# [277]	validation-rmse:6.54532
# [278]	validation-rmse:6.54528
# [279]	validation-rmse:6.54549
# [280]	validation-rmse:6.54556
# [281]	validation-rmse:6.54555
# [282]	validation-rmse:6.54548
# [283]	validation-rmse:6.54544
# [284]	validation-rmse:6.54552
# [285]	validation-rmse:6.54541
# [286]	validation-rmse:6.54528
# [287]	validation-rmse:6.54541
# [288]	validation-rmse:6.54531
# [289]	validation-rmse:6.54534
# [290]	validation-rmse:6.54545
# [291]	validation-rmse:6.54549
# [292]	validation-rmse:6.54551
# [293]	validation-rmse:6.54547
# [294]	validation-rmse:6.54542
# [295]	validation-rmse:6.54528
# [296]	validation-rmse:6.54530
# [297]	validation-rmse:6.54529
# [298]	validation-rmse:6.54528
# [299]	validation-rmse:6.54525
# [300]	validation-rmse:6.54518
# [301]	validation-rmse:6.54522
# [302]	validation-rmse:6.54531
# [303]	validation-rmse:6.54525
# [304]	validation-rmse:6.54524
# [305]	validation-rmse:6.54518
# [306]	validation-rmse:6.54512
# [307]	validation-rmse:6.54518
# [308]	validation-rmse:6.54518
# [309]	validation-rmse:6.54528
# [310]	validation-rmse:6.54533
# [311]	validation-rmse:6.54534
# [312]	validation-rmse:6.54535
# [313]	validation-rmse:6.54527
# [314]	validation-rmse:6.54524
# [315]	validation-rmse:6.54517
# [316]	validation-rmse:6.54517
# [317]	validation-rmse:6.54514
# [318]	validation-rmse:6.54510
# [319]	validation-rmse:6.54493
# [320]	validation-rmse:6.54499
# [321]	validation-rmse:6.54497
# [322]	validation-rmse:6.54504
# [323]	validation-rmse:6.54499
# [324]	validation-rmse:6.54496
# [325]	validation-rmse:6.54495
# [326]	validation-rmse:6.54490
# [327]	validation-rmse:6.54491
# [328]	validation-rmse:6.54492
# [329]	validation-rmse:6.54487
# [330]	validation-rmse:6.54487
# [331]	validation-rmse:6.54495
# [332]	validation-rmse:6.54489
# [333]	validation-rmse:6.54489
# [334]	validation-rmse:6.54482
# [335]	validation-rmse:6.54478
# [336]	validation-rmse:6.54482
# [337]	validation-rmse:6.54477
# [338]	validation-rmse:6.54477
# [339]	validation-rmse:6.54471
# [340]	validation-rmse:6.54456
# [341]	validation-rmse:6.54461
# [342]	validation-rmse:6.54459
# [343]	validation-rmse:6.54464
# [344]	validation-rmse:6.54468
# [345]	validation-rmse:6.54462
# [346]	validation-rmse:6.54462
# [347]	validation-rmse:6.54449
# [348]	validation-rmse:6.54448
# [349]	validation-rmse:6.54450
# [350]	validation-rmse:6.54452
# [351]	validation-rmse:6.54466
# [352]	validation-rmse:6.54467
# [353]	validation-rmse:6.54461
# [354]	validation-rmse:6.54454
# [355]	validation-rmse:6.54448
# [356]	validation-rmse:6.54454
# [357]	validation-rmse:6.54446
# [358]	validation-rmse:6.54444
# [359]	validation-rmse:6.54456
# [360]	validation-rmse:6.54448
# [361]	validation-rmse:6.54456
# [362]	validation-rmse:6.54447
# [363]	validation-rmse:6.54443
# [364]	validation-rmse:6.54445
# [365]	validation-rmse:6.54445
# [366]	validation-rmse:6.54439
# [367]	validation-rmse:6.54440
# [368]	validation-rmse:6.54440
# ...
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=538'>539</a> if allow_trials_fmin and hasattr(trials, "fmin"):
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=539'>540</a>     return trials.fmin(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=540'>541</a>         fn,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=541'>542</a>         space,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=542'>543</a>         algo=algo,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=543'>544</a>         max_evals=max_evals,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=544'>545</a>         timeout=timeout,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=545'>546</a>         loss_threshold=loss_threshold,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=546'>547</a>         max_queue_len=max_queue_len,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=547'>548</a>         rstate=rstate,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=548'>549</a>         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=549'>550</a>         verbose=verbose,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=550'>551</a>         catch_eval_exceptions=catch_eval_exceptions,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=551'>552</a>         return_argmin=return_argmin,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=552'>553</a>         show_progressbar=show_progressbar,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=553'>554</a>         early_stop_fn=early_stop_fn,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=554'>555</a>         trials_save_file=trials_save_file,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=555'>556</a>     )
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=557'>558</a> if trials is None:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=558'>559</a>     if os.path.exists(trials_save_file):
#
# File ~/yes/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=665'>666</a> # -- Stop-gap implementation!
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=666'>667</a> #    fmin should have been a Trials method in the first place
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=667'>668</a> #    but for now it's still sitting in another file.
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=668'>669</a> from .fmin import fmin
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=670'>671</a> return fmin(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=671'>672</a>     fn,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=672'>673</a>     space,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=673'>674</a>     algo=algo,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=674'>675</a>     max_evals=max_evals,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=675'>676</a>     timeout=timeout,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=676'>677</a>     loss_threshold=loss_threshold,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=677'>678</a>     trials=self,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=678'>679</a>     rstate=rstate,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=679'>680</a>     verbose=verbose,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=680'>681</a>     max_queue_len=max_queue_len,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=681'>682</a>     allow_trials_fmin=False,  # -- prevent recursion
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=682'>683</a>     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=683'>684</a>     catch_eval_exceptions=catch_eval_exceptions,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=684'>685</a>     return_argmin=return_argmin,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=685'>686</a>     show_progressbar=show_progressbar,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=686'>687</a>     early_stop_fn=early_stop_fn,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=687'>688</a>     trials_save_file=trials_save_file,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=688'>689</a> )
#
# File ~/yes/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=582'>583</a> rval.catch_eval_exceptions = catch_eval_exceptions
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=584'>585</a> # next line is where the fmin is actually executed
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=585'>586</a> rval.exhaust()
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=587'>588</a> if return_argmin:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=588'>589</a>     if len(trials.trials) == 0:
#
# File ~/yes/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=361'>362</a> def exhaust(self):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=362'>363</a>     n_done = len(self.trials)
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=363'>364</a>     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=364'>365</a>     self.trials.refresh()
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=365'>366</a>     return self
#
# File ~/yes/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=296'>297</a>     time.sleep(self.poll_interval_secs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=297'>298</a> else:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=298'>299</a>     # -- loop over trials and do the jobs directly
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=299'>300</a>     self.serial_evaluate()
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=301'>302</a> self.trials.refresh()
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=302'>303</a> if self.trials_save_file != "":
#
# File ~/yes/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=175'>176</a> ctrl = base.Ctrl(self.trials, current_trial=trial)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=176'>177</a> try:
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=177'>178</a>     result = self.domain.evaluate(spec, ctrl)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=178'>179</a> except Exception as e:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/fmin.py?line=179'>180</a>     logger.error("job exception: %s" % str(e))
#
# File ~/yes/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=882'>883</a> else:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=883'>884</a>     # -- the "work" of evaluating `config` can be written
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=884'>885</a>     #    either into the pyll part (self.expr)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=885'>886</a>     #    or the normal Python part (self.fn)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=886'>887</a>     pyll_rval = pyll.rec_eval(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=887'>888</a>         self.expr,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=888'>889</a>         memo=memo,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=889'>890</a>         print_node_on_error=self.rec_eval_print_node_on_error,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=890'>891</a>     )
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=891'>892</a>     rval = self.fn(pyll_rval)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=893'>894</a> if isinstance(rval, (float, int, np.number)):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/hyperopt/base.py?line=894'>895</a>     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# /home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb Cell 20' in objective(params)
#       <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019vscode-remote?line=2'>3</a> mlflow.set_tag("model", "xgboost")
#       <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019vscode-remote?line=3'>4</a> mlflow.log_params(params)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019vscode-remote?line=4'>5</a> booster = xgb.train(
#       <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019vscode-remote?line=5'>6</a>     params=params,
#       <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019vscode-remote?line=6'>7</a>     dtrain=train,
#       <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019vscode-remote?line=7'>8</a>     num_boost_round=1000,
#       <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019vscode-remote?line=8'>9</a>     evals=[(valid, 'validation')],
#      <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019vscode-remote?line=9'>10</a>     early_stopping_rounds=50
#      <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019vscode-remote?line=10'>11</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019vscode-remote?line=11'>12</a> y_pred = booster.predict(valid)
#      <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000019vscode-remote?line=12'>13</a> rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File ~/yes/lib/python3.9/site-packages/xgboost/core.py:532, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/core.py?line=529'>530</a> for k, arg in zip(sig.parameters, args):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/core.py?line=530'>531</a>     kwargs[k] = arg
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/core.py?line=531'>532</a> return f(**kwargs)
#
# File ~/yes/lib/python3.9/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/training.py?line=178'>179</a> if cb_container.before_iteration(bst, i, dtrain, evals):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/training.py?line=179'>180</a>     break
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/training.py?line=180'>181</a> bst.update(dtrain, i, obj)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/training.py?line=181'>182</a> if cb_container.after_iteration(bst, i, dtrain, evals):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/training.py?line=182'>183</a>     break
#
# File ~/yes/lib/python3.9/site-packages/xgboost/core.py:1733, in Booster.update(self, dtrain, iteration, fobj)
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/core.py?line=1729'>1730</a> self._validate_features(dtrain)
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/core.py?line=1731'>1732</a> if fobj is None:
# -> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/core.py?line=1732'>1733</a>     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/core.py?line=1733'>1734</a>                                             ctypes.c_int(iteration),
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/core.py?line=1734'>1735</a>                                             dtrain.handle))
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/core.py?line=1735'>1736</a> else:
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/xgboost/core.py?line=1736'>1737</a>     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=10,
        evals=[(valid, 'validation')],
        early_stopping_rounds=5
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# /home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb Cell 23' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000022vscode-remote?line=0'>1</a> with mlflow.start_run():
#       <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000022vscode-remote?line=2'>3</a>     train = xgb.DMatrix(X_train, label=y_train)
#       <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000022vscode-remote?line=3'>4</a>     valid = xgb.DMatrix(X_val, label=y_val)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/tracking/fluent.py:318, in start_run(run_id, experiment_id, run_name, nested, tags, description)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/fluent.py?line=313'>314</a>         user_specified_tags[MLFLOW_RUN_NAME] = run_name
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/fluent.py?line=315'>316</a>     resolved_tags = context_registry.resolve_tags(user_specified_tags)
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/fluent.py?line=317'>318</a>     active_run_obj = client.create_run(experiment_id=exp_id_for_run, tags=resolved_tags)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/fluent.py?line=319'>320</a> _active_run_stack.append(ActiveRun(active_run_obj))
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/fluent.py?line=320'>321</a> return _active_run_stack[-1]
#
# File ~/yes/lib/python3.9/site-packages/mlflow/tracking/client.py:265, in MlflowClient.create_run(self, experiment_id, start_time, tags)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/client.py?line=218'>219</a> def create_run(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/client.py?line=219'>220</a>     self,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/client.py?line=220'>221</a>     experiment_id: str,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/client.py?line=221'>222</a>     start_time: Optional[int] = None,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/client.py?line=222'>223</a>     tags: Optional[Dict[str, Any]] = None,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/client.py?line=223'>224</a> ) -> Run:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/client.py?line=224'>225</a>     """
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/client.py?line=225'>226</a>     Create a :py:class:`mlflow.entities.Run` object that can be associated with
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/client.py?line=226'>227</a>     metrics, parameters, artifacts, etc.
#    (...)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/client.py?line=262'>263</a>         status: RUNNING
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/client.py?line=263'>264</a>     """
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/client.py?line=264'>265</a>     return self._tracking_client.create_run(experiment_id, start_time, tags)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py:99, in TrackingServiceClient.create_run(self, experiment_id, start_time, tags)
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py?line=93'>94</a> # Extract user from tags
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py?line=94'>95</a> # This logic is temporary; the user_id attribute of runs is deprecated and will be removed
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py?line=95'>96</a> # in a later release.
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py?line=96'>97</a> user_id = tags.get(MLFLOW_USER, "unknown")
# ---> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py?line=98'>99</a> return self.store.create_run(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py?line=99'>100</a>     experiment_id=experiment_id,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py?line=100'>101</a>     user_id=user_id,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py?line=101'>102</a>     start_time=start_time or int(time.time() * 1000),
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py?line=102'>103</a>     tags=[RunTag(key, value) for (key, value) in tags.items()],
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py?line=103'>104</a> )
#
# File ~/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py:488, in FileStore.create_run(self, experiment_id, user_id, start_time, tags)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=483'>484</a> """
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=484'>485</a> Creates a run with the specified attributes.
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=485'>486</a> """
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=486'>487</a> experiment_id = FileStore.DEFAULT_EXPERIMENT_ID if experiment_id is None else experiment_id
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=487'>488</a> experiment = self.get_experiment(experiment_id)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=488'>489</a> if experiment is None:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=489'>490</a>     raise MlflowException(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=490'>491</a>         "Could not create run under experiment with ID %s - no such experiment "
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=491'>492</a>         "exists." % experiment_id,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=492'>493</a>         databricks_pb2.RESOURCE_DOES_NOT_EXIST,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=493'>494</a>     )
#
# File ~/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py:368, in FileStore.get_experiment(self, experiment_id)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=359'>360</a> """
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=360'>361</a> Fetch the experiment.
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=361'>362</a> Note: This API will search for active as well as deleted experiments.
#    (...)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=364'>365</a> :return: A single Experiment object if it exists, otherwise raises an Exception.
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=365'>366</a> """
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=366'>367</a> experiment_id = FileStore.DEFAULT_EXPERIMENT_ID if experiment_id is None else experiment_id
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=367'>368</a> experiment = self._get_experiment(experiment_id)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=368'>369</a> if experiment is None:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=369'>370</a>     raise MlflowException(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=370'>371</a>         "Experiment '%s' does not exist." % experiment_id,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=371'>372</a>         databricks_pb2.RESOURCE_DOES_NOT_EXIST,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=372'>373</a>     )
#
# File ~/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py:337, in FileStore._get_experiment(self, experiment_id, view_type)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=334'>335</a> experiment_dir = self._get_experiment_path(experiment_id, view_type)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=335'>336</a> if experiment_dir is None:
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=336'>337</a>     raise MlflowException(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=337'>338</a>         "Could not find experiment with ID %s" % experiment_id,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=338'>339</a>         databricks_pb2.RESOURCE_DOES_NOT_EXIST,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=339'>340</a>     )
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=340'>341</a> meta = read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=341'>342</a> if experiment_dir.startswith(self.trash_folder):
#
# MlflowException: Could not find experiment with ID 0

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb Cell 25' in <cell line: 6>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000024vscode-remote?line=11'>12</a> mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
#      <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000024vscode-remote?line=13'>14</a> mlmodel = model_class()
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000024vscode-remote?line=14'>15</a> mlmodel.fit(X_train, y_train)
#      <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000024vscode-remote?line=16'>17</a> y_pred = mlmodel.predict(X_val)
#      <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000024vscode-remote?line=17'>18</a> rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:557, in safe_patch.<locals>.safe_patch_function(*args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=554'>555</a>     patch_function.call(call_original, *args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=555'>556</a> else:
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=556'>557</a>     patch_function(call_original, *args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=558'>559</a> session.state = "succeeded"
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=560'>561</a> try_log_autologging_event(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=561'>562</a>     AutologgingEventLogger.get_logger().log_patch_function_success,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=562'>563</a>     session,
#    (...)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=566'>567</a>     kwargs,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=567'>568</a> )
#
# File ~/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:256, in with_managed_run.<locals>.patch_with_managed_run(original, *args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=252'>253</a>     managed_run = create_managed_run()
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=254'>255</a> try:
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=255'>256</a>     result = patch_function(original, *args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=256'>257</a> except (Exception, KeyboardInterrupt):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=257'>258</a>     # In addition to standard Python exceptions, handle keyboard interrupts to ensure
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=258'>259</a>     # that runs are terminated if a user prematurely interrupts training execution
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=259'>260</a>     # (e.g. via sigint / ctrl-c)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=260'>261</a>     if managed_run:
#
# File ~/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py:1502, in _autolog.<locals>.patched_fit(fit_impl, original, self, *args, **kwargs)
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1497'>1498</a> if t.should_log():
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1498'>1499</a>     # In `fit_mlflow` call, it will also call metric API for computing training metrics
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1499'>1500</a>     # so we need temporarily disable the post_training_metrics patching.
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1500'>1501</a>     with _AUTOLOGGING_METRICS_MANAGER.disable_log_post_training_metrics():
# -> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1501'>1502</a>         result = fit_impl(original, self, *args, **kwargs)
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1502'>1503</a>     if should_log_post_training_metrics:
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1503'>1504</a>         _AUTOLOGGING_METRICS_MANAGER.register_model(
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1504'>1505</a>             self, mlflow.active_run().info.run_id
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1505'>1506</a>         )
#
# File ~/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py:1306, in _autolog.<locals>.fit_mlflow(original, self, *args, **kwargs)
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1303'>1304</a> _log_pretraining_metadata(autologging_client, self, *args, **kwargs)
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1304'>1305</a> params_logging_future = autologging_client.flush(synchronous=False)
# -> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1305'>1306</a> fit_output = original(self, *args, **kwargs)
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1306'>1307</a> _log_posttraining_metadata(autologging_client, self, *args, **kwargs)
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1307'>1308</a> autologging_client.flush(synchronous=True)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:538, in safe_patch.<locals>.safe_patch_function.<locals>.call_original(*og_args, **og_kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=534'>535</a>         original_result = original(*_og_args, **_og_kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=535'>536</a>         return original_result
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=537'>538</a> return call_original_fn_with_event_logging(_original_fn, og_args, og_kwargs)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:473, in safe_patch.<locals>.safe_patch_function.<locals>.call_original_fn_with_event_logging(original_fn, og_args, og_kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=463'>464</a> try:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=464'>465</a>     try_log_autologging_event(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=465'>466</a>         AutologgingEventLogger.get_logger().log_original_function_start,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=466'>467</a>         session,
#    (...)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=470'>471</a>         og_kwargs,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=471'>472</a>     )
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=472'>473</a>     original_fn_result = original_fn(*og_args, **og_kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=474'>475</a>     try_log_autologging_event(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=475'>476</a>         AutologgingEventLogger.get_logger().log_original_function_success,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=476'>477</a>         session,
#    (...)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=480'>481</a>         og_kwargs,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=481'>482</a>     )
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=482'>483</a>     return original_fn_result
#
# File ~/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:535, in safe_patch.<locals>.safe_patch_function.<locals>.call_original.<locals>._original_fn(*_og_args, **_og_kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=526'>527</a> # Show all non-MLflow warnings as normal (i.e. not as event logs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=527'>528</a> # during original function execution, even if silent mode is enabled
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=528'>529</a> # (`silent=True`), since these warnings originate from the ML framework
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=529'>530</a> # or one of its dependencies and are likely relevant to the caller
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=530'>531</a> with set_non_mlflow_warnings_behavior_for_current_thread(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=531'>532</a>     disable_warnings=False,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=532'>533</a>     reroute_warnings=False,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=533'>534</a> ):
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=534'>535</a>     original_result = original(*_og_args, **_og_kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=535'>536</a>     return original_result
#
# File ~/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:450, in BaseForest.fit(self, X, y, sample_weight)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=438'>439</a> trees = [
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=439'>440</a>     self._make_estimator(append=False, random_state=random_state)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=440'>441</a>     for i in range(n_more_estimators)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=441'>442</a> ]
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=443'>444</a> # Parallel loop: we prefer the threading backend as the Cython code
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=444'>445</a> # for fitting the trees is internally releasing the Python GIL
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=445'>446</a> # making threading more efficient than multiprocessing in
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=446'>447</a> # that case. However, for joblib 0.12+ we respect any
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=447'>448</a> # parallel_backend contexts set at a higher level,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=448'>449</a> # since correctness does not rely on using threads.
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=449'>450</a> trees = Parallel(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=450'>451</a>     n_jobs=self.n_jobs,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=451'>452</a>     verbose=self.verbose,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=452'>453</a>     **_joblib_parallel_args(prefer="threads"),
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=453'>454</a> )(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=454'>455</a>     delayed(_parallel_build_trees)(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=455'>456</a>         t,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=456'>457</a>         self,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=457'>458</a>         X,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=458'>459</a>         y,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=459'>460</a>         sample_weight,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=460'>461</a>         i,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=461'>462</a>         len(trees),
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=462'>463</a>         verbose=self.verbose,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=463'>464</a>         class_weight=self.class_weight,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=464'>465</a>         n_samples_bootstrap=n_samples_bootstrap,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=465'>466</a>     )
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=466'>467</a>     for i, t in enumerate(trees)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=467'>468</a> )
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=469'>470</a> # Collect newly grown trees
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=470'>471</a> self.estimators_.extend(trees)
#
# File ~/yes/lib/python3.9/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=1042'>1043</a> if self.dispatch_one_batch(iterator):
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=1043'>1044</a>     self._iterating = self._original_iterator is not None
# -> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=1045'>1046</a> while self.dispatch_one_batch(iterator):
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=1046'>1047</a>     pass
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=1048'>1049</a> if pre_dispatch == "all" or n_jobs == 1:
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=1049'>1050</a>     # The iterable was consumed all at once by the above for loop.
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=1050'>1051</a>     # No need to wait for async callbacks to trigger to
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=1051'>1052</a>     # consumption.
#
# File ~/yes/lib/python3.9/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=858'>859</a>     return False
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=859'>860</a> else:
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=860'>861</a>     self._dispatch(tasks)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=861'>862</a>     return True
#
# File ~/yes/lib/python3.9/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=776'>777</a> with self._lock:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=777'>778</a>     job_idx = len(self._jobs)
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=778'>779</a>     job = self._backend.apply_async(batch, callback=cb)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=779'>780</a>     # A job can complete so quickly than its callback is
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=780'>781</a>     # called before we get here, causing self._jobs to
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=781'>782</a>     # grow. To ensure correct results ordering, .insert is
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=782'>783</a>     # used (rather than .append) in the following line
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=783'>784</a>     self._jobs.insert(job_idx, job)
#
# File ~/yes/lib/python3.9/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=205'>206</a> def apply_async(self, func, callback=None):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=206'>207</a>     """Schedule a func to be run"""
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=207'>208</a>     result = ImmediateResult(func)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=208'>209</a>     if callback:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=209'>210</a>         callback(result)
#
# File ~/yes/lib/python3.9/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=568'>569</a> def __init__(self, batch):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=569'>570</a>     # Don't delay the application, to avoid keeping the input
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=570'>571</a>     # arguments in memory
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/_parallel_backends.py?line=571'>572</a>     self.results = batch()
#
# File ~/yes/lib/python3.9/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=257'>258</a> def __call__(self):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=258'>259</a>     # Set the default nested backend to self._backend but do not set the
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=259'>260</a>     # change the default number of processes to -1
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=260'>261</a>     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=261'>262</a>         return [func(*args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=262'>263</a>                 for func, args, kwargs in self.items]
#
# File ~/yes/lib/python3.9/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=257'>258</a> def __call__(self):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=258'>259</a>     # Set the default nested backend to self._backend but do not set the
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=259'>260</a>     # change the default number of processes to -1
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=260'>261</a>     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=261'>262</a>         return [func(*args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/joblib/parallel.py?line=262'>263</a>                 for func, args, kwargs in self.items]
#
# File ~/yes/lib/python3.9/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/utils/fixes.py?line=213'>214</a> def __call__(self, *args, **kwargs):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/utils/fixes.py?line=214'>215</a>     with config_context(**self.config):
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/utils/fixes.py?line=215'>216</a>         return self.function(*args, **kwargs)
#
# File ~/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:185, in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=181'>182</a>     elif class_weight == "balanced_subsample":
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=182'>183</a>         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=184'>185</a>     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=185'>186</a> else:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/ensemble/_forest.py?line=186'>187</a>     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:557, in safe_patch.<locals>.safe_patch_function(*args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=554'>555</a>     patch_function.call(call_original, *args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=555'>556</a> else:
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=556'>557</a>     patch_function(call_original, *args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=558'>559</a> session.state = "succeeded"
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=560'>561</a> try_log_autologging_event(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=561'>562</a>     AutologgingEventLogger.get_logger().log_patch_function_success,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=562'>563</a>     session,
#    (...)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=566'>567</a>     kwargs,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=567'>568</a> )
#
# File ~/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:256, in with_managed_run.<locals>.patch_with_managed_run(original, *args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=252'>253</a>     managed_run = create_managed_run()
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=254'>255</a> try:
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=255'>256</a>     result = patch_function(original, *args, **kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=256'>257</a> except (Exception, KeyboardInterrupt):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=257'>258</a>     # In addition to standard Python exceptions, handle keyboard interrupts to ensure
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=258'>259</a>     # that runs are terminated if a user prematurely interrupts training execution
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=259'>260</a>     # (e.g. via sigint / ctrl-c)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=260'>261</a>     if managed_run:
#
# File ~/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py:1509, in _autolog.<locals>.patched_fit(fit_impl, original, self, *args, **kwargs)
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1506'>1507</a>     return result
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1507'>1508</a> else:
# -> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/sklearn/__init__.py?line=1508'>1509</a>     return original(self, *args, **kwargs)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:538, in safe_patch.<locals>.safe_patch_function.<locals>.call_original(*og_args, **og_kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=534'>535</a>         original_result = original(*_og_args, **_og_kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=535'>536</a>         return original_result
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=537'>538</a> return call_original_fn_with_event_logging(_original_fn, og_args, og_kwargs)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:473, in safe_patch.<locals>.safe_patch_function.<locals>.call_original_fn_with_event_logging(original_fn, og_args, og_kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=463'>464</a> try:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=464'>465</a>     try_log_autologging_event(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=465'>466</a>         AutologgingEventLogger.get_logger().log_original_function_start,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=466'>467</a>         session,
#    (...)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=470'>471</a>         og_kwargs,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=471'>472</a>     )
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=472'>473</a>     original_fn_result = original_fn(*og_args, **og_kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=474'>475</a>     try_log_autologging_event(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=475'>476</a>         AutologgingEventLogger.get_logger().log_original_function_success,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=476'>477</a>         session,
#    (...)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=480'>481</a>         og_kwargs,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=481'>482</a>     )
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=482'>483</a>     return original_fn_result
#
# File ~/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py:535, in safe_patch.<locals>.safe_patch_function.<locals>.call_original.<locals>._original_fn(*_og_args, **_og_kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=526'>527</a> # Show all non-MLflow warnings as normal (i.e. not as event logs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=527'>528</a> # during original function execution, even if silent mode is enabled
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=528'>529</a> # (`silent=True`), since these warnings originate from the ML framework
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=529'>530</a> # or one of its dependencies and are likely relevant to the caller
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=530'>531</a> with set_non_mlflow_warnings_behavior_for_current_thread(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=531'>532</a>     disable_warnings=False,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=532'>533</a>     reroute_warnings=False,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=533'>534</a> ):
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=534'>535</a>     original_result = original(*_og_args, **_og_kwargs)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/autologging_utils/safety.py?line=535'>536</a>     return original_result
#
# File ~/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py:1315, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1277'>1278</a> def fit(
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1278'>1279</a>     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1279'>1280</a> ):
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1280'>1281</a>     """Build a decision tree regressor from the training set (X, y).
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1281'>1282</a>
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1282'>1283</a>     Parameters
#    (...)
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1311'>1312</a>         Fitted estimator.
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1312'>1313</a>     """
# -> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1314'>1315</a>     super().fit(
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1315'>1316</a>         X,
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1316'>1317</a>         y,
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1317'>1318</a>         sample_weight=sample_weight,
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1318'>1319</a>         check_input=check_input,
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1319'>1320</a>         X_idx_sorted=X_idx_sorted,
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1320'>1321</a>     )
#    <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=1321'>1322</a>     return self
#
# File ~/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py:420, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=408'>409</a> else:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=409'>410</a>     builder = BestFirstTreeBuilder(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=410'>411</a>         splitter,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=411'>412</a>         min_samples_split,
#    (...)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=416'>417</a>         self.min_impurity_decrease,
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=417'>418</a>     )
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=419'>420</a> builder.build(self.tree_, X, y, sample_weight)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=421'>422</a> if self.n_outputs_ == 1 and is_classifier(self):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/sklearn/tree/_classes.py?line=422'>423</a>     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
import mlflow
logged_model = 'runs:/47f7464c74e74a1abb1ef0c9d9d21360/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.xgboost.load_model(logged_model)

# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(valid)
# Out:
# ---------------------------------------------------------------------------
# MissingConfigException                    Traceback (most recent call last)
# /home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb Cell 27' in <cell line: 5>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000026vscode-remote?line=1'>2</a> logged_model = 'runs:/47f7464c74e74a1abb1ef0c9d9d21360/models_mlflow'
#       <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000026vscode-remote?line=3'>4</a> # Load model as a PyFuncModel.
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000026vscode-remote?line=4'>5</a> loaded_model = mlflow.xgboost.load_model(logged_model)
#       <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000026vscode-remote?line=6'>7</a> # Predict on a Pandas DataFrame.
#       <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000026vscode-remote?line=7'>8</a> import pandas as pd
#
# File ~/yes/lib/python3.9/site-packages/mlflow/xgboost/__init__.py:334, in load_model(model_uri, dst_path)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/xgboost/__init__.py?line=312'>313</a> def load_model(model_uri, dst_path=None):
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/xgboost/__init__.py?line=313'>314</a>     """
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/xgboost/__init__.py?line=314'>315</a>     Load an XGBoost model from a local file or a run.
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/xgboost/__init__.py?line=315'>316</a>
#    (...)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/xgboost/__init__.py?line=331'>332</a>              models, depending on the saved model class specification.
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/xgboost/__init__.py?line=332'>333</a>     """
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/xgboost/__init__.py?line=333'>334</a>     local_model_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/xgboost/__init__.py?line=334'>335</a>     flavor_conf = _get_flavor_configuration(local_model_path, FLAVOR_NAME)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/xgboost/__init__.py?line=335'>336</a>     _add_code_from_conf_to_system_path(local_model_path, flavor_conf)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py:94, in _download_artifact_from_uri(artifact_uri, output_path)
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=90'>91</a>     parsed_uri = parsed_uri._replace(path=posixpath.dirname(parsed_uri.path))
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=91'>92</a>     root_uri = prefix + urllib.parse.urlunparse(parsed_uri)
# ---> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=93'>94</a> return get_artifact_repository(artifact_uri=root_uri).download_artifacts(
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=94'>95</a>     artifact_path=artifact_path, dst_path=output_path
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=95'>96</a> )
#
# File ~/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py:107, in get_artifact_repository(artifact_uri)
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=96'>97</a> def get_artifact_repository(artifact_uri):
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=97'>98</a>     """Get an artifact repository from the registry based on the scheme of artifact_uri
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=98'>99</a>
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=99'>100</a>     :param artifact_uri: The artifact store URI. This URI is used to select which artifact
#    (...)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=104'>105</a>              requirements.
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=105'>106</a>     """
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=106'>107</a>     return _artifact_repository_registry.get_artifact_repository(artifact_uri)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py:73, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri)
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=65'>66</a> if repository is None:
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=66'>67</a>     raise MlflowException(
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=67'>68</a>         "Could not find a registered artifact repository for: {}. "
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=68'>69</a>         "Currently registered schemes are: {}".format(
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=69'>70</a>             artifact_uri, list(self._registry.keys())
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=70'>71</a>         )
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=71'>72</a>     )
# ---> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repository_registry.py?line=72'>73</a> return repository(artifact_uri)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/store/artifact/runs_artifact_repo.py:26, in RunsArtifactRepository.__init__(self, artifact_uri)
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/runs_artifact_repo.py?line=22'>23</a> from mlflow.store.artifact.artifact_repository_registry import get_artifact_repository
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/runs_artifact_repo.py?line=24'>25</a> super().__init__(artifact_uri)
# ---> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/runs_artifact_repo.py?line=25'>26</a> uri = RunsArtifactRepository.get_underlying_uri(artifact_uri)
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/runs_artifact_repo.py?line=26'>27</a> self.repo = get_artifact_repository(uri)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/store/artifact/runs_artifact_repo.py:39, in RunsArtifactRepository.get_underlying_uri(runs_uri)
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/runs_artifact_repo.py?line=36'>37</a> (run_id, artifact_path) = RunsArtifactRepository.parse_runs_uri(runs_uri)
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/runs_artifact_repo.py?line=37'>38</a> tracking_uri = get_databricks_profile_uri_from_artifact_uri(runs_uri)
# ---> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/runs_artifact_repo.py?line=38'>39</a> uri = get_artifact_uri(run_id, artifact_path, tracking_uri)
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/runs_artifact_repo.py?line=39'>40</a> assert not RunsArtifactRepository.is_runs_uri(uri)  # avoid an infinite loop
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/artifact/runs_artifact_repo.py?line=40'>41</a> return add_databricks_profile_info_to_artifact_uri(uri, tracking_uri)
#
# File ~/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py:47, in get_artifact_uri(run_id, artifact_path, tracking_uri)
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=40'>41</a>     raise MlflowException(
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=41'>42</a>         message="A run_id must be specified in order to obtain an artifact uri!",
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=42'>43</a>         error_code=INVALID_PARAMETER_VALUE,
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=43'>44</a>     )
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=45'>46</a> store = _get_store(tracking_uri)
# ---> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=46'>47</a> run = store.get_run(run_id)
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=47'>48</a> # Maybe move this method to RunsArtifactRepository so the circular dependency is clearer.
#      <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py?line=48'>49</a> assert urllib.parse.urlparse(run.info.artifact_uri).scheme != "runs"  # avoid an infinite loop
#
# File ~/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py:530, in FileStore.get_run(self, run_id)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=525'>526</a> """
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=526'>527</a> Note: Will get both active and deleted runs.
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=527'>528</a> """
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=528'>529</a> _validate_run_id(run_id)
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=529'>530</a> run_info = self._get_run_info(run_id)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=530'>531</a> if run_info is None:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=531'>532</a>     raise MlflowException(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=532'>533</a>         "Run '%s' metadata is in invalid state." % run_id, databricks_pb2.INVALID_STATE
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=533'>534</a>     )
#
# File ~/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py:552, in FileStore._get_run_info(self, run_uuid)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=547'>548</a> if run_dir is None:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=548'>549</a>     raise MlflowException(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=549'>550</a>         "Run '%s' not found" % run_uuid, databricks_pb2.RESOURCE_DOES_NOT_EXIST
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=550'>551</a>     )
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=551'>552</a> run_info = self._get_run_info_from_dir(run_dir)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=552'>553</a> if run_info.experiment_id != exp_id:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=553'>554</a>     raise MlflowException(
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=554'>555</a>         "Run '%s' metadata is in invalid state." % run_uuid, databricks_pb2.INVALID_STATE
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=555'>556</a>     )
#
# File ~/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py:560, in FileStore._get_run_info_from_dir(self, run_dir)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=558'>559</a> def _get_run_info_from_dir(self, run_dir):
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=559'>560</a>     meta = read_yaml(run_dir, FileStore.META_DATA_FILE_NAME)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=560'>561</a>     run_info = _read_persisted_run_info_dict(meta)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py?line=561'>562</a>     return run_info
#
# File ~/yes/lib/python3.9/site-packages/mlflow/utils/file_utils.py:179, in read_yaml(root, file_name)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/file_utils.py?line=176'>177</a> file_path = os.path.join(root, file_name)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/file_utils.py?line=177'>178</a> if not exists(file_path):
# --> <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/file_utils.py?line=178'>179</a>     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/file_utils.py?line=179'>180</a> try:
#     <a href='file:///home/ubuntu/yes/lib/python3.9/site-packages/mlflow/utils/file_utils.py?line=180'>181</a>     with codecs.open(file_path, mode="r", encoding=ENCODING) as yaml_file:
#
# MissingConfigException: Yaml file '/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/mlruns/1/47f7464c74e74a1abb1ef0c9d9d21360/meta.yaml' does not exist.

# %%
loaded_model.best_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb Cell 28' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bmlops-zoomcamp/home/ubuntu/mlops-zoomcamp/02-experiment-tracking/duration-prediction.ipynb#ch0000030vscode-remote?line=0'>1</a> loaded_model.best_score
#
# NameError: name 'loaded_model' is not defined
